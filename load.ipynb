# %%
pip install sideseeing-tools

# %%
from sideseeing_tools import sideseeing, plot

# %%
ds = sideseeing.SideSeeingDS('my-dataset-folder')

# %%
i = ds.instance
i

# %%
i.wifi_networks

# %%
i.cell_networks

# %%
i.media_start_time, i.media_stop_time, i.media_total_time

# %%
i.files

# %%
i.extract_snippet(0, 227, 'outputs/my-snippet-1')

# %%
i.extract_frames_at_times(output_dir='outputs/my-snippet-2', times=[0, 5, 10.5], prefix='test_', left_zeros=3)

# %%
i.extract_frames_at_positions(output_dir='outputs/my-snippet-3', positions=[0, 150, 315], prefix='test_', left_zeros=4)

# %%
i.extract_frames(output_dir='outputs/my-snippet-4', step=100, prefix='test_', left_zeros=4)

# %%
i.extract_frames_timespan(output_dir='outputs/my-snippet-5', start_time=0, end_time=10, step=30, prefix='test_', left_zeros=4)

# %%
plotter = plot.SideSeeingPlotter(ds)

# %%
plotter.plot_instance_sensors3_and_audio(i)
